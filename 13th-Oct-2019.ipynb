# %% [markdown]
# # Titanic Survival

# %%
import pandas as mits
data = mits.read_csv("https://raw.githubusercontent.com/sumathi16/MITS_FDP_Adv_Python/master/titanic.csv")
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.shape[0] # No of passengers
# Out:
# 891

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# check the help for
# - mits.read_csv<br>
# and identify the parameter to read data if your dataset consists tab seperated values.

# %%
help(mits.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers:
#
# read_csv(filepath_or_buffer, sep=',', delimiter=None, header='infer', names=None, index_col=None, usecols=None, squeeze=False, prefix=None, mangle_dupe_cols=True, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skipinitialspace=False, skiprows=None, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, skip_blank_lines=True, parse_dates=False, infer_datetime_format=False, keep_date_col=False, date_parser=None, dayfirst=False, iterator=False, chunksize=None, compression='infer', thousands=None, decimal=b'.', lineterminator=None, quotechar='"', quoting=0, escapechar=None, comment=None, encoding=None, dialect=None, tupleize_cols=None, error_bad_lines=True, warn_bad_lines=True, skipfooter=0, doublequote=True, delim_whitespace=False, low_memory=True, memory_map=False, float_precision=None)
#     Read CSV (comma-separated) file into DataFrame
#
# ...

# %%
m = mits.read_csv("marks.csv")
m
# Out:
#    Name  Marks
# 0  raju     77
# 1  ravi     67
# 2  hari     56

# %%
m1 = mits.read_csv("marks.tsv",sep='\t')
m1
# Out:
#    Name  Marks
# 0  raju     77
# 1  ravi     67
# 2  hari     56

# %%
df = mits.read_csv("https://raw.githubusercontent.com/sumathi16/MITS_FDP_Adv_Python/master/titanic.csv",\
                  usecols=['Survived','Pclass','Name','Sex','Age'])
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age
# 0    male  22.0
# 1  female  38.0
# 2  female  26.0
# 3  female  35.0
# 4    male  35.0

# %%
m2 = mits.read_csv("marks.csv",names=['Name','Marks'])
m2
# Out:
#    Name  Marks
# 0  raju     77
# 1  ravi     67
# 2  hari     56

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
df.describe(include='object')
# Out:
#                              Name   Sex
# count                         891   891
# unique                        891     2
# top     Widener, Mr. Harry Elkins  male
# freq                            1   577

# %%
df.describe(include='int64')
# Out:
#          Survived      Pclass
# count  891.000000  891.000000
# mean     0.383838    2.308642
# std      0.486592    0.836071
# min      0.000000    1.000000
# 25%      0.000000    2.000000
# 50%      0.000000    3.000000
# 75%      1.000000    3.000000
# max      1.000000    3.000000

# %%
data.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                       Name   Sex  \
# count    891.000000  891.000000  891.000000                        891   891
# unique          NaN         NaN         NaN                        891     2
# top             NaN         NaN         NaN  Widener, Mr. Harry Elkins  male
# freq            NaN         NaN         NaN                          1   577
# mean     446.000000    0.383838    2.308642                        NaN   NaN
# std      257.353842    0.486592    0.836071                        NaN   NaN
# min        1.000000    0.000000    1.000000                        NaN   NaN
# 25%      223.500000    0.000000    2.000000                        NaN   NaN
# 50%      446.000000    0.000000    3.000000                        NaN   NaN
# 75%      668.500000    1.000000    3.000000                        NaN   NaN
# max      891.000000    1.000000    3.000000                        NaN   NaN
#
# ...

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df['Sex'].value_counts().index
# Out:
# Index(['male', 'female'], dtype='object')

# %%
type(df['Sex'].value_counts())
# Out:
# pandas.core.series.Series

# %%
df['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df['Name'].nunique()
# Out:
# 891

# %%
df['Name'].value_counts()
# Out:
# Widener, Mr. Harry Elkins                                   1
# Bissette, Miss. Amelia                                      1
# Beckwith, Mrs. Richard Leonard (Sallie Monypeny)            1
# Hold, Mr. Stephen                                           1
# Petterson, Mr. Johan Emil                                   1
# Shutes, Miss. Elizabeth W                                   1
# Johansson, Mr. Gustaf Joel                                  1
# Cann, Mr. Ernest Charles                                    1
# Taussig, Miss. Ruth                                         1
# O'Brien, Mr. Timothy                                        1
# Vestrom, Miss. Hulda Amanda Adolfina                        1
# Futrelle, Mr. Jacques Heath                                 1
# Goodwin, Miss. Lillian Amy                                  1
# Johansson, Mr. Karl Johan                                   1
# Calderhead, Mr. Edward Pennington                           1
# ...

# %%
data['Sex'].nunique()
# Out:
# 2

# %%
data['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
data['Fare'][:10]
# Out:
# 0     7.2500
# 1    71.2833
# 2     7.9250
# 3    53.1000
# 4     8.0500
# 5     8.4583
# 6    51.8625
# 7    21.0750
# 8    11.1333
# 9    30.0708
# Name: Fare, dtype: float64

# %%
data[['Fare','SibSp']][:10]
# Out:
#       Fare  SibSp
# 0   7.2500      1
# 1  71.2833      1
# 2   7.9250      0
# 3  53.1000      1
# 4   8.0500      0
# 5   8.4583      0
# 6  51.8625      0
# 7  21.0750      3
# 8  11.1333      0
# 9  30.0708      1

# %%
data[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-80a4aab09c73> in <module>()
# ----> 1 data[0]
#
# ...

# %%
m3 = mits.read_csv('marks.csv')
m3
# Out:
#    raju  77
# 0  ravi  67
# 1  hari  56

# %%
m3["77"]
# Out:
# 0    67
# 1    56
# Name: 77, dtype: int64

# %%
data.iloc[:,3:5]
# Out:
#                                                   Name     Sex
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# 5                                     Moran, Mr. James    male
# 6                              McCarthy, Mr. Timothy J    male
# 7                       Palsson, Master. Gosta Leonard    male
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female
# 10                     Sandstrom, Miss. Marguerite Rut  female
# 11                            Bonnell, Miss. Elizabeth  female
# 12                      Saundercock, Mr. William Henry    male
# 13                         Andersson, Mr. Anders Johan    male
# ...

# %%
data.loc[:,"Name":"Ticket"]
# Out:
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# ...

# %%
data.iloc[49:70,3:5]
# Out:
#                                                  Name     Sex
# 49      Arnold-Franchi, Mrs. Josef (Josefine Franchi)  female
# 50                         Panula, Master. Juha Niilo    male
# 51                       Nosworthy, Mr. Richard Cater    male
# 52           Harper, Mrs. Henry Sleeper (Myna Haxtun)  female
# 53  Faunthorpe, Mrs. Lizzie (Elizabeth Anne Wilkin...  female
# 54                     Ostby, Mr. Engelhart Cornelius    male
# 55                                  Woolner, Mr. Hugh    male
# 56                                  Rugg, Miss. Emily  female
# 57                                Novel, Mr. Mansouer    male
# 58                       West, Miss. Constance Mirium  female
# 59                 Goodwin, Master. William Frederick    male
# 60                              Sirayanian, Mr. Orsen    male
# 61                                Icard, Miss. Amelie  female
# 62                        Harris, Mr. Henry Birkhardt    male
# ...

# %%
data_name = data.set_index("Name")
data_name.head()
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
#
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                     SibSp  Parch  \
# ...

# %%
data.Name[:10]
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
data_name.loc["Braund, Mr. Owen Harris":"Allen, Mr. William Henry",
              "Age":"Ticket"]
# Out:
#                                                      Age  SibSp  Parch  \
# Name
# Braund, Mr. Owen Harris                             22.0      1      0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  38.0      1      0
# Heikkinen, Miss. Laina                              26.0      0      0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        35.0      1      0
# Allen, Mr. William Henry                            35.0      0      0
#
#                                                               Ticket
# Name
# Braund, Mr. Owen Harris                                    A/5 21171
# Cumings, Mrs. John Bradley (Florence Briggs Tha...          PC 17599
# Heikkinen, Miss. Laina                              STON/O2. 3101282
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  113803
# Allen, Mr. William Henry                                      373450

# %%
data_name.iloc[0:4,4:8]
# Out:
#                                                      Age  SibSp  Parch  \
# Name
# Braund, Mr. Owen Harris                             22.0      1      0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  38.0      1      0
# Heikkinen, Miss. Laina                              26.0      0      0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        35.0      1      0
#
#                                                               Ticket
# Name
# Braund, Mr. Owen Harris                                    A/5 21171
# Cumings, Mrs. John Bradley (Florence Briggs Tha...          PC 17599
# Heikkinen, Miss. Laina                              STON/O2. 3101282
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  113803

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
print(data.columns)
print(data.dtypes)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
import numpy as np
data.dtypes == np.object
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
data.columns[data.dtypes == np.object]
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
data.columns[data.dtypes == np.int64]
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'SibSp', 'Parch'], dtype='object')

# %%
data.columns[(data.dtypes == np.int64) | (data.dtypes == np.float64)]
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
data[data.columns[data.dtypes == np.object]]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# 5                                     Moran, Mr. James    male
# 6                              McCarthy, Mr. Timothy J    male
# 7                       Palsson, Master. Gosta Leonard    male
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female
# 10                     Sandstrom, Miss. Marguerite Rut  female
# 11                            Bonnell, Miss. Elizabeth  female
# 12                      Saundercock, Mr. William Henry    male
# 13                         Andersson, Mr. Anders Johan    male
# ...

# %%
data.drop('Name',axis=1)
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0              1         0       3    male  22.0      1      0
# 1              2         1       1  female  38.0      1      0
# 2              3         1       3  female  26.0      0      0
# 3              4         1       1  female  35.0      1      0
# 4              5         0       3    male  35.0      0      0
# 5              6         0       3    male   NaN      0      0
# 6              7         0       1    male  54.0      0      0
# 7              8         0       3    male   2.0      3      1
# 8              9         1       3  female  27.0      0      2
# 9             10         1       2  female  14.0      1      0
# 10            11         1       3  female   4.0      1      1
# 11            12         1       1  female  58.0      0      0
# 12            13         0       3    male  20.0      0      0
# 13            14         0       3    male  39.0      1      5
# ...

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#data = data.drop("Name",axis=1) #Overwrites original dataframe
data.drop("Name",axis=1,inplace=True)
#data1 = data.drop("Name",axis=1)

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data['Cabin'].isnull().sum()
# Out:
# 687

# %%
data.drop("Cabin",axis=1,inplace=True)

# %%
data.shape
# Out:
# (891, 10)

# %%
data['Age'].isnull()[:10]
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6    False
# 7    False
# 8    False
# 9    False
# Name: Age, dtype: bool

# %%
data['Age'][data['Age'].isnull()][:5]
# Out:
# 5    NaN
# 17   NaN
# 19   NaN
# 26   NaN
# 28   NaN
# Name: Age, dtype: float64

# %%
data['Age'].median(),data['Age'].mean(),data['Age'].max(),data['Age'].min()
# Out:
# (28.0, 29.69911764705882, 80.0, 0.42)

# %%
data['Age'][data['Age'].isnull()] = data['Age'].median()
data['Age'].isnull().sum()
# Out:
# C:\Users\krish\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# 0

# %%
data['Embarked'][data['Embarked'].isnull()]
# Out:
# 61     NaN
# 829    NaN
# Name: Embarked, dtype: object

# %%
data.isnull().sum().sum()
# Out:
# 2

# %%
help(data.dropna)
# Out:
# Help on method dropna in module pandas.core.frame:
#
# dropna(axis=0, how='any', thresh=None, subset=None, inplace=False) method of pandas.core.frame.DataFrame instance
#     Remove missing values.
#
#     See the :ref:`User Guide <missing_data>` for more on which values are
#     considered missing, and how to work with missing data.
#
#     Parameters
#     ----------
#     axis : {0 or 'index', 1 or 'columns'}, default 0
#         Determine if rows or columns which contain missing values are
#         removed.
#
#         * 0, or 'index' : Drop rows which contain missing values.
#         * 1, or 'columns' : Drop columns which contain missing value.
#
#         .. deprecated:: 0.23.0: Pass tuple or list to drop on multiple
#         axes.
#     how : {'any', 'all'}, default 'any'
#         Determine if row or column is removed from DataFrame, when we have
#         at least one NA or all NA.
#
#         * 'any' : If any NA values are present, drop that row or column.
# ...

# %%
data.dropna(inplace=True)
data.shape
# Out:
# (889, 10)

# %%
data1 = mits.read_csv("https://raw.githubusercontent.com/sumathi16/MITS_FDP_Adv_Python/master/titanic.csv")
data1.shape
# Out:
# (891, 12)

# %%
data1.dropna(axis=1,inplace=True)
data1.shape
# Out:
# (891, 9)

# %%
data1.dropna(inplace=True)
data1.shape
# Out:
# (183, 12)

# %%
data.shape
# Out:
# (889, 10)

# %%
data.Sex.value_counts()
# Out:
# male      577
# female    312
# Name: Sex, dtype: int64

# %%
dir(data)
# Out:
# ['Age',
#  'Embarked',
#  'Fare',
#  'Parch',
#  'PassengerId',
#  'Pclass',
#  'Sex',
#  'SibSp',
#  'Survived',
#  'T',
#  'Ticket',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
# ...

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
data.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000168F42A4D30>,
# ...
#       dtype=object)

# %%
data['Age'].hist()

# %%
plt.hist(data['Age'])
# Out:
# (array([ 54.,  46., 177., 346., 117.,  70.,  45.,  23.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data['Age'][data['Age']>50])
# Out:
# (array([14., 15.,  9., 10.,  7.,  1.,  5.,  1.,  0.,  1.]),
#  array([51. , 53.9, 56.8, 59.7, 62.6, 65.5, 68.4, 71.3, 74.2, 77.1, 80. ]),
#  <a list of 10 Patch objects>)

# %%
plt.boxplot(data['Age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x168f5bede48>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x168f5bf7780>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x168f5bedcf8>],
#  'medians': [<matplotlib.lines.Line2D at 0x168f5bf7fd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x168f5c00438>],
#  'means': []}

# %%
plt.bar(data['Sex'].value_counts().index,data['Sex'].value_counts())
# Out:
# <BarContainer object of 2 artists>

# %%
plt.bar(data['Embarked'].value_counts().index,data['Embarked'].value_counts())
# Out:
# <BarContainer object of 3 artists>

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0            1         0       3    male  22.0      1      0
# 1            2         1       1  female  38.0      1      0
# 2            3         1       3  female  26.0      0      0
# 3            4         1       1  female  35.0      1      0
# 4            5         0       3    male  35.0      0      0
#
#              Ticket     Fare Embarked
# 0         A/5 21171   7.2500        S
# 1          PC 17599  71.2833        C
# 2  STON/O2. 3101282   7.9250        S
# 3            113803  53.1000        S
# 4            373450   8.0500        S

# %%
data = mits.get_dummies(data)
data.shape
# Out:
# (889, 692)

# %%
target = data['Survived']
target[:2]
# Out:
# 0    0
# 1    1
# Name: Survived, dtype: int64

# %%
features = data.drop("Survived",axis=1)
features.shape
# Out:
# (889, 691)
